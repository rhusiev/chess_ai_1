# %% [markdown]
# # To download tensors from another account

# %%
# !pip install gdown

import gdown

to_download = {
    'https://drive.google.com/file/d/1-gaNBls4IYP5LORGeFlbBF_oahlVCE5O/view?usp=drive_link': 'matrices_puzzles_tensor.pt',
    'https://drive.google.com/file/d/1-hDXfRmKDmmGFtzkuIMM3eUvDm9gxmED/view?usp=drive_link': 'start_distributions_puzzles_tensor.pt',
    'https://drive.google.com/file/d/1-rvM3nnL-8b2f91g3TLgepk_kDj70gKk/view?usp=drive_link': 'real_starts_puzzles_tensor.pt',
    'https://drive.google.com/file/d/1-uzvIiPTPo07_dz-5aEUS2GuaT9f8zdx/view?usp=drive_link': 'end_distributions_puzzles_tensor.pt',
    # 'https://drive.google.com/file/d/13zlhMGQ9VbvgMgAsaUJk2nAd37ylIBAD/view?usp=sharing': 'tactics_end_distributions.pt',
    # 'https://drive.google.com/file/d/13sop7egYeI1yIIB0MkJqjTIx-WiKKpQa/view?usp=sharing': 'tactics_matrices_tensor.pt',
    # 'https://drive.google.com/file/d/13x5i89At0AB23-gtdGY2gbBZ1y3TFJVs/view?usp=sharing': 'tactics_real_starts.pt',
    # 'https://drive.google.com/file/d/13ub7zmLKSTgInuvIcrztt6gjb2R0yzGM/view?usp=sharing': 'tactics_start_distributions.pt',
    # 'https://drive.google.com/file/d/1iV7VVllmQ57U4GZBzOfW-CPDS8rWcBto/view?usp=sharing': 'end_distributions_400_tensor.pt',
    # 'https://drive.google.com/file/d/1-5kCmrZXM3Q4Q5CcnO3l1cWI-CHdeG5H/view?usp=sharing': 'end_distributions_800_tensor.pt',
    # 'https://drive.google.com/file/d/1-BL9CbrAwwnWHknBnkBSFg7Ekmq-tSIr/view?usp=sharing': 'end_distributions_1200_tensor.pt',
    # 'https://drive.google.com/file/d/1Oao8lHX4gqPuYBv_6yRqZbhmsj8_Ie-r/view?usp=sharing': 'matrices_400_tensor.pt',
    # 'https://drive.google.com/file/d/1--3PLWWHLMtah95L2psrPF_QLypgNkiu/view?usp=sharing': 'matrices_800_tensor.pt',
    # 'https://drive.google.com/file/d/1-6_qc9x2SEghCvINTRfDicsG2-h66aSZ/view?usp=sharing': 'matrices_1200_tensor.pt',
    # 'https://drive.google.com/file/d/117RSwPpIzkeiV4GFmhS974yqRNpn6rE0/view?usp=sharing': 'real_starts_400_tensor.pt',
    # 'https://drive.google.com/file/d/1-0BHsu1IZ96X86-ySq5TzV1xXgXVDx1h/view?usp=sharing': 'real_starts_800_tensor.pt',
    # 'https://drive.google.com/file/d/1-AWsNY5Sbs3mvDEOkneJvXxOd-06JGMP/view?usp=sharing': 'real_starts_1200_tensor.pt',
    # 'https://drive.google.com/file/d/1i0R1WIvN7sJruIv-__w68KchcAme378Q/view?usp=sharing': 'start_distributions_400_tensor.pt',
    # 'https://drive.google.com/file/d/1ZXsDRMW20dJcxdeFrMK6XYa8ynvuZs9D/view?usp=sharing': 'start_distributions_800_tensor.pt',
    # 'https://drive.google.com/file/d/1zpsy9Y83DESPxP5hfcHzd9m5LaDyEhCU/view?usp=sharing': 'start_distributions_1200_tensor.pt',
    # 'https://drive.google.com/file/d/1-DQHxpuIxJWbaeX4MJZRJCmJFjqfR8-9/view?usp=sharing': 'end_distributions_1600_tensor.pt',
    # 'https://drive.google.com/file/d/1-Jv41Bfx9hckh-GNGUPIogtLoZ0IpGSn/view?usp=sharing': 'end_distributions_2000_tensor.pt',
    # 'https://drive.google.com/file/d/1-NHI62rMWF-GfSaFELTvbpz6UEFCT9Rt/view?usp=sharing': 'end_distributions_2400_tensor.pt',
    # 'https://drive.google.com/file/d/1-SCylhrTjZH7DY5ucRNvXmXIF1aINgtQ/view?usp=sharing': 'end_distributions_2800_tensor.pt',
    # 'https://drive.google.com/file/d/1-Uq86wH2yT6H0fIozOO1ZJd9UMRYSQ3K/view?usp=sharing': 'end_distributions_3200_tensor.pt',
    # 'https://drive.google.com/file/d/1-B_UkAjoCsRV3XI-VauKccLaAjKsIYs3/view?usp=sharing': 'matrices_1600_tensor.pt',
    # 'https://drive.google.com/file/d/1-DSIHETGsC1YcerJgGJgwdemxIjlQLt9/view?usp=sharing': 'matrices_2000_tensor.pt',
    # 'https://drive.google.com/file/d/1-Krzk-qLAQbutyAyYwc85WGafR0Ir3Ar/view?usp=sharing': 'matrices_2400_tensor.pt',
    # 'https://drive.google.com/file/d/1-PJQKY3VuhPT7KCHlVR8tmoCR-Ti54ft/view?usp=sharing': 'matrices_2800_tensor.pt',
    # 'https://drive.google.com/file/d/1-T8tDgUpHzI4RcVvSVi9fH2yh7XgiO-J/view?usp=sharing': 'matrices_3200_tensor.pt',
    # 'https://drive.google.com/file/d/1-DEY2TYK10GTE1iCfbsGHvOPd9PzOZUy/view?usp=sharing': 'real_starts_1600_tensor.pt',
    # 'https://drive.google.com/file/d/1-Ffz9LC0LK95BGWh_vRPaJB_pyJ_kgcC/view?usp=sharing': 'real_starts_2000_tensor.pt',
    # 'https://drive.google.com/file/d/1-LdyoN8RdDnCVcG2mzGZhx7HjsOvO4Do/view?usp=sharing': 'real_starts_2400_tensor.pt',
    # 'https://drive.google.com/file/d/1-Pmm7eDgcndsuNlFhZ_4Lk5mDE1tbT4O/view?usp=sharing': 'real_starts_2800_tensor.pt',
    # 'https://drive.google.com/file/d/1-UA6A3cvmzu-Yt5VMgStQKjtUdmrH4S3/view?usp=sharing': 'real_starts_3200_tensor.pt',
    # 'https://drive.google.com/file/d/1-D-J8jT441L9mMoM0LL2WdFsL9Y9HkCk/view?usp=sharing': 'start_distributions_1600_tensor.pt',
    # 'https://drive.google.com/file/d/1-EM7PAFdifk_otY3f5Rk4uxD6omow80B/view?usp=sharing': 'start_distributions_2000_tensor.pt',
    # 'https://drive.google.com/file/d/1-LEOmOk2_nRONBmMir5UJunvRyUHssTS/view?usp=sharing': 'start_distributions_2400_tensor.pt',
    # 'https://drive.google.com/file/d/1-PkM_sOTK4aVpnzRzkumaVLEmujXdx9C/view?usp=sharing': 'start_distributions_2800_tensor.pt',
    # 'https://drive.google.com/file/d/1-T_6Zx6rFhUevH7kmApXv_JkvOX9I8z1/view?usp=sharing': 'start_distributions_3200_tensor.pt',
}

for url, path in to_download.items():
    output_path = f'drive/MyDrive/Colab Notebooks/tensors/{path}'
    gdown.download(url, output_path, quiet=False,fuzzy=True)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1-gaNBls4IYP5LORGeFlbBF_oahlVCE5O
# To: /content/drive/MyDrive/Colab Notebooks/tensors/matrices_puzzles_tensor.pt
# 100%|██████████| 1.53G/1.53G [00:13<00:00, 111MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-hDXfRmKDmmGFtzkuIMM3eUvDm9gxmED
# To: /content/drive/MyDrive/Colab Notebooks/tensors/start_distributions_puzzles_tensor.pt
# 100%|██████████| 128M/128M [00:00<00:00, 186MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-rvM3nnL-8b2f91g3TLgepk_kDj70gKk
# To: /content/drive/MyDrive/Colab Notebooks/tensors/real_starts_puzzles_tensor.pt
# 100%|██████████| 128M/128M [00:00<00:00, 222MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-uzvIiPTPo07_dz-5aEUS2GuaT9f8zdx
# To: /content/drive/MyDrive/Colab Notebooks/tensors/end_distributions_puzzles_tensor.pt
# ...

# %% [markdown]
# # Imports

# %%
import pickle

import numpy as np
import torch

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Create tensors. Skip to next header, if they are already present

# %%
for i in range(2400, 2801, 400):
    elo = (i, i + 400)
    just_matrices = np.load(f"drive/MyDrive/Colab Notebooks/data/matrices_{elo[1]}.npy")
    with open(f"drive/MyDrive/Colab Notebooks/data/values_{elo[1]}.pkl", "rb") as f:
        just_values = pickle.load(f)

    start_distributions = []
    real_starts = []
    end_distributions = []
    for board_state in just_values:
        distribution = np.zeros((64,))
        prob_sum = 0
        for (start, end), probability in board_state:
            distribution += np.array(start) * probability
            prob_sum += probability
        if prob_sum:
            distribution /= prob_sum
        else:
            distribution = np.zeros((64,))
        start_distributions.append(distribution)
        real_starts.append(np.array(start).reshape((1, 8, 8)))
        end_distributions.append(end)

    matrices_tensor = torch.Tensor(just_matrices)
    start_distributions_tensor = torch.Tensor(start_distributions)
    real_starts_tensor = torch.Tensor(real_starts)
    end_distributions_tensor = torch.Tensor(end_distributions)

    print(matrices_tensor.shape, torch.isnan(matrices_tensor).any())
    print(start_distributions_tensor.shape, torch.isnan(start_distributions_tensor).any())
    print(real_starts_tensor.shape, torch.isnan(real_starts_tensor).any())
    print(end_distributions_tensor.shape, torch.isnan(end_distributions_tensor).any())

    torch.save(matrices_tensor, f"drive/MyDrive/Colab Notebooks/tensors/matrices_{elo[1]}_tensor.pt")
    torch.save(
        start_distributions_tensor, f"drive/MyDrive/Colab Notebooks/tensors/start_distributions_{elo[1]}_tensor.pt"
    )
    torch.save(real_starts_tensor, f"drive/MyDrive/Colab Notebooks/tensors/real_starts_{elo[1]}_tensor.pt")
    torch.save(
        end_distributions_tensor, f"drive/MyDrive/Colab Notebooks/tensors/end_distributions_{elo[1]}_tensor.pt"
    )

    for j in (
        matrices_tensor,
        start_distributions_tensor,
        real_starts_tensor,
        end_distributions_tensor,
        just_matrices,
        just_values,
        start_distributions,
        real_starts,
        end_distributions
    ):
        del j
     
    torch.cuda.empty_cache()

# %% [markdown]
# # Start from here, if tensors are already present

# %%
class ChessNetwork(torch.nn.Module):
    r"""A chess network that predicts the best move.

        The network takes in a 12x8x8 matrix representing the board state
        and outputs two 64-length vectors representing the probability distribution of
        each square being the best move to move from and to.
        The probability distribution of squares to move to is calculated only for the
        best square to move from.

        12x8x8 matrix:
            - 12 - one matrix 8x8 for each piece type(6 white, 6 black). It consists of
                1s and 0s, where 1s represent the presence of a piece of that type in
                that square:
                - 0-5: White pieces:
                    - 0: Pawns
                    - 1: Knights
                    - 2: Bishops
                    - 3: Rooks
                    - 4: Queens
                    - 5: King
                - 6-11: Black pieces, same as above

        White pieces are shown in the first 6 matrices, black pieces in the last 6
        If a king can castle kingside, the value is 2, if queenside, 3, if both, 4
        If a piece is the network's, it is represented by a 1, if enemy's, by -1


        The network is composed of four parts:
        - A preprocessor that takes in the board state and outputs a 128-length vector.
        This is used to extract features from the board state and is shared between the
        start and end predictors.
        - A start predictor that takes in the preprocessed board state and outputs a
        64-length vector representing the probability distribution of the best square
        to move from
        - A move preprocessor that takes in the best square to move from and outputs a
        128-length vector
        - An end predictor that takes in the preprocessed board state and the move
        preprocessor output and outputs a 64-length vector representing the probability

        The network can be shown as:
                   Input
                     |
                   Preprocessor
                 /              \\
                |                |
    Move from <-Start Predictor  |
                |                |
            Move Preprocessor    |
                \\              /
                  End Predictor -> Move to
    """

    def __init__(self) -> None:
        super().__init__()
        self.preprocessor = torch.nn.Sequential(
            torch.nn.Conv2d(12, 128, kernel_size=3, padding=1),
            torch.nn.ReLU(),
            torch.nn.Conv2d(128, 7, kernel_size=3, padding=1),
            torch.nn.Flatten(),
            torch.nn.Linear(7*8*8, 200),
            torch.nn.Sigmoid(),
            torch.nn.Linear(200, 128),
            torch.nn.ReLU(),
        )
        self.move_preprocessor = torch.nn.Sequential(
            torch.nn.Conv2d(1, 3, kernel_size=3, padding=1),
            torch.nn.Flatten(),
            torch.nn.Linear(128+64, 128),
            torch.nn.ReLU(),
        )
        self.start_predictor = torch.nn.Sequential(
            torch.nn.Linear(128, 160),
            torch.nn.Sigmoid(),
            torch.nn.Linear(160, 100),
            torch.nn.ReLU(),
            torch.nn.Linear(100, 64),
            torch.nn.Softmax(dim=1),
        )
        self.end_predictor = torch.nn.Sequential(
            torch.nn.Linear(256, 140),
            torch.nn.ReLU(),
            torch.nn.Linear(140, 64),
            torch.nn.Softmax(dim=1),
        )


    def forward(
        self,
        x: torch.Tensor,
        start_sequence: torch.Tensor | None = None,
        only_start: bool = False,
    ) -> tuple[torch.Tensor, torch.Tensor]:
        """Forward pass of the network.

        Args:
            x (torch.Tensor): The board state as a 12x8x8 matrix
            start_sequence (torch.Tensor, optional): a 1x8x8 matrix representing the
                best square to move from. Defaults to None.
            only_start (bool, optional): Whether to only return the from square.
                Defaults to False.

        Returns:
            tuple[torch.Tensor, torch.Tensor]: The probability distributions of the
                best square to move from and to
        """
        head = self.preprocessor(x)
        start = self.start_predictor(head)
        if start_sequence is None:
            start_sequence = torch.zeros((x.shape[0], 1, 8, 8), dtype=torch.float32).to(
                device
            )
            # Find max
            for i in range(start.shape[0]):
                start_sequence[i, 0, start[i].argmax() // 8, start[i].argmax() % 8] = 1

        if only_start:
            return start, start_sequence

        move = self.move_preprocessor(start_sequence)
        head = torch.cat((head, move), dim=1)
        return start, self.end_predictor(head)

    def train_on_a_batch(
        self,
        batch: torch.Tensor,
        optimizer: torch.optim.Optimizer,
        loss_function: torch.nn.modules.loss._Loss,
        expected_starts: torch.Tensor,
        real_starts: torch.Tensor | None = None,
        expected_ends: torch.Tensor | None = None,
    ) -> float:
        """Train the network on a batch of data.

        Args:
            batch (torch.Tensor): The board states as a 12x8x8 matrix each
            optimizer (torch.optim.Optimizer): The optimizer to use for training
            loss_function (torch.nn.modules.loss._Loss): The loss function to use
            expected_starts (torch.Tensor): The expected start squares as a 64-length
                vectors
            real_starts (torch.Tensor, optional): The real start vector of 1x8x8
                matrices. Defaults to None.
            expected_ends (torch.Tensor, optional): The expected end squares as a
                64-length vector. Defaults to None.

        Returns:
            float: The loss
        """
        optimizer.zero_grad()
        start, end = self(batch, real_starts)
        loss = loss_function(start, expected_starts)
        if expected_ends is not None:
            loss += loss_function(end, expected_ends)
        loss.backward()
        optimizer.step()
        return loss.item()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device} device")
BATCH_SIZE = 2000
EPOCHS = 300
# Out:
# Using cuda device

# %%
model = ChessNetwork().to(device)
start_elo = 2800
start_epoch = 40
model.load_state_dict(
    torch.load(
        f"drive/MyDrive/Colab Notebooks/250k/model_elo_newest_{start_elo}_epoch_{start_epoch}.pth",
        map_location=device,
    )
)  # If load existing
print(f"Loaded a model from {start_epoch} epoch")
print(f"Num params: {sum(p.numel() for p in model.parameters())}")
print(f"Preprocessor params: {sum(p.numel() for p in model.preprocessor.parameters())}")
move_preprocessor_params = sum(p.numel() for p in model.move_preprocessor.parameters())
print(f"Move Preprocessor params: {move_preprocessor_params}")
print(f"Start params: {sum(p.numel() for p in model.start_predictor.parameters())}")
print(f"End params: {sum(p.numel() for p in model.end_predictor.parameters())}")
optimiser = torch.optim.Adam(model.parameters(), lr=0.001)
loss_function = torch.nn.CrossEntropyLoss()
# Out:
# Loaded a model from 600 epoch
# Num params: 250493
# Preprocessor params: 137551
# Move Preprocessor params: 24734
# Start params: 43204
# End params: 45004

# %%
def train_elo(matrices_tensor,
              start_distributions_tensor,
              real_starts_tensor,
              end_distributions_tensor,
              elo,
              start_epoch=0):
    if elo[1] == 400 or elo[1] >= 2400:
        epochs = EPOCHS * 3
    elif elo[1] == 800:
        epochs = EPOCHS * 2
    else:
        epochs = EPOCHS
    epochs += 1
    train(matrices_tensor,
              start_distributions_tensor,
              real_starts_tensor,
              end_distributions_tensor,
              epochs,
              start_epoch=0)


def train(matrices_tensor,
              start_distributions_tensor,
              real_starts_tensor,
              end_distributions_tensor,
              epochs,
              start_epoch=0,
              elo=(0, "tactics")):
    print("---")
    print(f"Training on {elo[1]:<4} elo, {epochs:<3} epochs")
    print("---")
    matrices_length = len(matrices_tensor)
    for j in range(start_epoch, epochs):
        loss = None
        print(f"Epoch {j:<3}", end=" |  ")
        for i in range(0, matrices_length, BATCH_SIZE):
            batch = matrices_tensor[i : i + BATCH_SIZE].to(device)
            expected_starts = start_distributions_tensor[i : i + BATCH_SIZE].to(device)
            real_starts = real_starts_tensor[i : i + BATCH_SIZE].to(device)
            expected_ends = end_distributions_tensor[i : i + BATCH_SIZE].to(device)
            loss = model.train_on_a_batch(
                batch, optimiser, loss_function, expected_starts, real_starts, expected_ends
            )

        if loss is not None:
            print(round(loss, 4))
        if j % 20 == 0:
            print(f"Saving {j} epoch network...")
            torch.save(
                model.state_dict(), f"drive/MyDrive/Colab Notebooks/250k/model_elo_{elo[1]}_epoch_{j}.pth"
            )

# %%
for e in range(start_elo - 400, 1600, 400):
    elo = (e, e + 400)
    matrices_tensor = torch.load(f"drive/MyDrive/Colab Notebooks/tensors/matrices_{elo[1]}_tensor.pt")
    start_distributions_tensor = torch.load(
        f"drive/MyDrive/Colab Notebooks/tensors/start_distributions_{elo[1]}_tensor.pt"
    )
    real_starts_tensor = torch.load(f"drive/MyDrive/Colab Notebooks/tensors/real_starts_{elo[1]}_tensor.pt")
    end_distributions_tensor = torch.load(
        f"drive/MyDrive/Colab Notebooks/tensors/end_distributions_{elo[1]}_tensor.pt"
    )
    train_elo(matrices_tensor, start_distributions_tensor, real_starts_tensor, end_distributions_tensor, elo, start_epoch)
    if start_epoch:
        start_epoch = 0
# Out:
# ---
# Training on 800  elo, 600 epochs
# ---
# Epoch 0   |  8.0415
# Saving 0 epoch network...
# Epoch 1   |  8.0015
# Epoch 2   |  7.948
# Epoch 3   |  7.9208
# Epoch 4   |  7.9109
# Epoch 5   |  7.8931
# Epoch 6   |  7.8978
# Epoch 7   |  7.8808
# Epoch 8   |  7.8429
# Epoch 9   |  7.8436
# Epoch 10  |  7.841
# Epoch 11  |  7.8301
# Epoch 12  |  7.8344
# Epoch 13  |  7.8206
# Epoch 14  |  7.8231
# Epoch 15  |  7.8199
# Epoch 16  |  7.815
# Epoch 17  |  7.8083
# Epoch 18  |  7.8056
# Epoch 19  |  7.7988
# Epoch 20  |  7.7942
# Saving 20 epoch network...
# Epoch 21  |  7.7916
# Epoch 22  |  7.7857
# Epoch 23  |  7.7905
# Epoch 24  |  7.7856
# Epoch 25  |  7.7901
# Epoch 26  |  7.7793
# Epoch 27  |  7.7686
# Epoch 28  |  7.7618
# Epoch 29  |  7.7607
# Epoch 30  |  7.7464
# Epoch 31  |  7.7462
# Epoch 32  |  7.7324
# Epoch 33  |  7.7201
# Epoch 34  |  7.7025
# Epoch 35  |  7.6965
# Epoch 36  |  7.7009
# Epoch 37  |  7.6927
# Epoch 38  |  7.6874
# Epoch 39  |  7.6835
# ...

# %%
matrices_tensor = torch.load(f"drive/MyDrive/Colab Notebooks/tensors/tactics_matrices_tensor.pt")
start_distributions_tensor = torch.load(
    f"drive/MyDrive/Colab Notebooks/tensors/tactics_start_distributions.pt"
)
real_starts_tensor = torch.load(f"drive/MyDrive/Colab Notebooks/tensors/tactics_real_starts.pt")
end_distributions_tensor = torch.load(
    f"drive/MyDrive/Colab Notebooks/tensors/tactics_end_distributions.pt"
)
epochs = EPOCHS * 3
print("---")
print(f"Training on  tactics, {epochs:<3} epochs")
print("---")
epochs += 1
train(matrices_tensor,
            start_distributions_tensor,
            real_starts_tensor,
            end_distributions_tensor,
            epochs,
            start_epoch=600)
# Out:
# ---
# Training on  tactics, 900 epochs
# ---
# Epoch 600 |  6.7386
# Saving 600 epoch network...
# Epoch 601 |  6.7519
# Epoch 602 |  6.7455
# Epoch 603 |  6.7441
# Epoch 604 |  6.7468
# Epoch 605 |  6.7575
# Epoch 606 |  6.7469
# Epoch 607 |  6.7459
# Epoch 608 |  6.7534
# Epoch 609 |  6.7409
# Epoch 610 |  6.7488
# Epoch 611 |  6.7488
# Epoch 612 |  6.7438
# Epoch 613 |  6.7569
# Epoch 614 |  6.748
# Epoch 615 |  6.7468
# Epoch 616 |  6.7384
# Epoch 617 |  6.7383
# Epoch 618 |  6.7515
# Epoch 619 |  6.7429
# Epoch 620 |  6.7327
# Saving 620 epoch network...
# Epoch 621 |  6.7416
# Epoch 622 |  6.7385
# Epoch 623 |  6.7383
# Epoch 624 |  6.7402
# Epoch 625 |  6.7434
# Epoch 626 |  6.7441
# Epoch 627 |  6.7416
# Epoch 628 |  6.7481
# Epoch 629 |  6.7337
# Epoch 630 |  6.7377
# Epoch 631 |  6.7423
# Epoch 632 |  6.7382
# Epoch 633 |  6.7351
# Epoch 634 |  6.7408
# Epoch 635 |  6.739
# Epoch 636 |  6.7398
# Epoch 637 |  6.7329
# Epoch 638 |  6.7436
# Epoch 639 |  6.7462
# ...

# %%
for e in range(1600, 2801, 400):
    elo = (e, e + 400)
    matrices_tensor = torch.load(f"drive/MyDrive/Colab Notebooks/tensors/matrices_{elo[1]}_tensor.pt")
    start_distributions_tensor = torch.load(
        f"drive/MyDrive/Colab Notebooks/tensors/start_distributions_{elo[1]}_tensor.pt"
    )
    real_starts_tensor = torch.load(f"drive/MyDrive/Colab Notebooks/tensors/real_starts_{elo[1]}_tensor.pt")
    end_distributions_tensor = torch.load(
        f"drive/MyDrive/Colab Notebooks/tensors/end_distributions_{elo[1]}_tensor.pt"
    )
    train(matrices_tensor, start_distributions_tensor, real_starts_tensor, end_distributions_tensor, EPOCHS * 2, 0, (0, f"new_{elo[1]}"))
    if start_epoch:
        start_epoch = 0
# Out:
# Epoch 0   |  7.8467
# Saving 0 epoch network...
# Epoch 1   |  7.833
# Epoch 2   |  7.8267
# Epoch 3   |  7.8128
# Epoch 4   |  7.8031
# Epoch 5   |  7.7926
# Epoch 6   |  7.8042
# Epoch 7   |  7.7964
# Epoch 8   |  7.7899
# Epoch 9   |  7.802
# Epoch 10  |  7.7981
# Epoch 11  |  7.8031
# Epoch 12  |  7.7957
# Epoch 13  |  7.8099
# Epoch 14  |  7.7923
# Epoch 15  |  7.7905
# Epoch 16  |  7.7934
# Epoch 17  |  7.7876
# Epoch 18  |  7.7677
# Epoch 19  |  7.7717
# Epoch 20  |  7.7684
# Saving 20 epoch network...
# Epoch 21  |  7.7762
# Epoch 22  |  7.7621
# Epoch 23  |  7.7776
# Epoch 24  |  7.75
# Epoch 25  |  7.7761
# Epoch 26  |  7.7671
# Epoch 27  |  7.7591
# Epoch 28  |  7.7614
# Epoch 29  |  7.7465
# Epoch 30  |  7.7582
# Epoch 31  |  7.7435
# Epoch 32  |  7.7664
# Epoch 33  |  7.7685
# Epoch 34  |  7.761
# Epoch 35  |  7.7724
# Epoch 36  |  7.7579
# Epoch 37  |  7.7523
# Epoch 38  |  7.7455
# Epoch 39  |  7.7568
# Epoch 40  |  7.752
# Saving 40 epoch network...
# ...

# %%
matrices_tensor = torch.load(f"drive/MyDrive/Colab Notebooks/tensors/matrices_puzzles_tensor.pt")
start_distributions_tensor = torch.load(
    f"drive/MyDrive/Colab Notebooks/tensors/start_distributions_puzzles_tensor.pt"
)
real_starts_tensor = torch.load(f"drive/MyDrive/Colab Notebooks/tensors/real_starts_puzzles_tensor.pt")
end_distributions_tensor = torch.load(
    f"drive/MyDrive/Colab Notebooks/tensors/end_distributions_puzzles_tensor.pt"
)
epochs = EPOCHS * 3
print("---")
print(f"Training on  puzzles, {epochs:<3} epochs")
print("---")
epochs += 1
train(matrices_tensor,
            start_distributions_tensor,
            real_starts_tensor,
            end_distributions_tensor,
            epochs,
            start_epoch=0,
            elo=(0, "puzzles"))
# Out:
# ---
# Training on  puzzles, 900 epochs
# ---
# Epoch 0   |  6.833
# Saving 0 epoch network...
# Epoch 1   |  6.8366
# Epoch 2   |  6.8346
# Epoch 3   |  6.8264
# Epoch 4   |  6.8312
# Epoch 5   |  6.8372
# Epoch 6   |  6.8434
# Epoch 7   |  6.8404
# Epoch 8   |  6.8284
# Epoch 9   |  6.8234
# Epoch 10  |  6.822
# Epoch 11  |  6.8232
# Epoch 12  |  6.8243
# Epoch 13  |  6.8133
# Epoch 14  |  6.8185
# Epoch 15  |  6.816
# Epoch 16  |  6.82
# Epoch 17  |  6.8221
# Epoch 18  |  6.8219
# Epoch 19  |  6.8143
# Epoch 20  |  6.8249
# Saving 20 epoch network...
# Epoch 21  |  6.8159
# Epoch 22  |  6.8123
# Epoch 23  |  6.8213
# Epoch 24  |  6.8166
# Epoch 25  |  6.8176
# Epoch 26  |  6.8129
# Epoch 27  |  6.8127
# Epoch 28  |  6.8112
# Epoch 29  |  6.8168
# Epoch 30  |  6.8107
# Epoch 31  |  6.8126
# Epoch 32  |  6.8107
# Epoch 33  |  6.805
# Epoch 34  |  6.8058
# Epoch 35  |  6.8058
# Epoch 36  |  6.8109
# Epoch 37  |  6.8084
# Epoch 38  |  6.8168
# Epoch 39  |  6.81
# Epoch 40  |  6.7969
# ...

# %%
for e in range(2400, 2801, 400):
    elo = (e, e + 400)
    matrices_tensor = torch.load(f"drive/MyDrive/Colab Notebooks/tensors/matrices_{elo[1]}_tensor.pt")
    start_distributions_tensor = torch.load(
        f"drive/MyDrive/Colab Notebooks/tensors/start_distributions_{elo[1]}_tensor.pt"
    )
    real_starts_tensor = torch.load(f"drive/MyDrive/Colab Notebooks/tensors/real_starts_{elo[1]}_tensor.pt")
    end_distributions_tensor = torch.load(
        f"drive/MyDrive/Colab Notebooks/tensors/end_distributions_{elo[1]}_tensor.pt"
    )
    train(matrices_tensor, start_distributions_tensor, real_starts_tensor, end_distributions_tensor, EPOCHS * 2, 40, (0, f"newest_{elo[1]}"))
    if start_epoch:
        start_epoch = 0
# Out:
# Epoch 0   |  7.8672
# Saving 0 epoch network...
# Epoch 1   |  7.8473
# Epoch 2   |  7.8394
# Epoch 3   |  7.8266
# Epoch 4   |  7.8214
# Epoch 5   |  7.8146
# Epoch 6   |  7.8139
# Epoch 7   |  7.8242
# Epoch 8   |  7.8284
# Epoch 9   |  7.8081
# Epoch 10  |  7.8272
# Epoch 11  |  7.8372
# Epoch 12  |  7.8175
# Epoch 13  |  7.8148
# Epoch 14  |  7.81
# Epoch 15  |  7.8133
# Epoch 16  |  7.8027
# Epoch 17  |  7.8089
# Epoch 18  |  7.8165
# Epoch 19  |  7.8122
# Epoch 20  |  7.8108
# Saving 20 epoch network...
# Epoch 21  |  7.8031
# Epoch 22  |  7.8059
# Epoch 23  |  7.8076
# Epoch 24  |  7.7964
# Epoch 25  |  7.7894
# Epoch 26  |  7.8094
# Epoch 27  |  7.7959
# Epoch 28  |  7.7836
# Epoch 29  |  7.7999
# Epoch 30  |  7.7912
# Epoch 31  |  7.7913
# Epoch 32  |  7.786
# Epoch 33  |  7.789
# Epoch 34  |  7.783
# Epoch 35  |  7.7999
# Epoch 36  |  7.7885
# Epoch 37  |  7.7923
# Epoch 38  |  7.7997
# Epoch 39  |  7.7749
# Epoch 40  |  7.774
# Saving 40 epoch network...
# ...

# %%
matrices_tensor = torch.load(f"drive/MyDrive/Colab Notebooks/tensors/matrices_puzzles_tensor.pt")
matrices_tensor = torch.cat(
    (matrices_tensor, torch.load(f"drive/MyDrive/Colab Notebooks/tensors/matrices_2400_tensor.pt")), dim=0
)
matrices_tensor = torch.cat(
    (matrices_tensor, torch.load(f"drive/MyDrive/Colab Notebooks/tensors/matrices_2800_tensor.pt")), dim=0
)
start_distributions_tensor = torch.load(
    f"drive/MyDrive/Colab Notebooks/tensors/start_distributions_puzzles_tensor.pt"
)
start_distributions_tensor = torch.cat(
    (start_distributions_tensor, torch.load(f"drive/MyDrive/Colab Notebooks/tensors/start_distributions_2400_tensor.pt")),
    dim=0,
)
start_distributions_tensor = torch.cat(
    (start_distributions_tensor, torch.load(f"drive/MyDrive/Colab Notebooks/tensors/start_distributions_2800_tensor.pt")),
    dim=0,
)
real_starts_tensor = torch.load(f"drive/MyDrive/Colab Notebooks/tensors/real_starts_puzzles_tensor.pt")
real_starts_tensor = torch.cat(
    (real_starts_tensor, torch.load(f"drive/MyDrive/Colab Notebooks/tensors/real_starts_2400_tensor.pt")), dim=0
)
real_starts_tensor = torch.cat(
    (real_starts_tensor, torch.load(f"drive/MyDrive/Colab Notebooks/tensors/real_starts_2800_tensor.pt")), dim=0
)
end_distributions_tensor = torch.load(
    f"drive/MyDrive/Colab Notebooks/tensors/end_distributions_puzzles_tensor.pt"
)
end_distributions_tensor = torch.cat(
    (end_distributions_tensor, torch.load(f"drive/MyDrive/Colab Notebooks/tensors/end_distributions_2400_tensor.pt")),
    dim=0,
)
end_distributions_tensor = torch.cat(
    (end_distributions_tensor, torch.load(f"drive/MyDrive/Colab Notebooks/tensors/end_distributions_2800_tensor.pt")),
    dim=0,
)

# %%
epochs = EPOCHS*4
train(matrices_tensor,
            start_distributions_tensor,
            real_starts_tensor,
            end_distributions_tensor,
            epochs,
            start_epoch=0,
            elo=(0, "all"))
